# %% [markdown]
# ## Преобразования функций и полиномы. Домашнее задание
#
# С помощью SymPy найдите полиномы, описывающие данные наборы точек. Затем проведите полное исследование каждого полученного полинома: проверьте четность/нечетность, найдите нули, промежутки знакопостоянства. Постройте их графики. С помощью изменения промежутка для х добейтесь того, чтобы все нули были отображены на графике функции.<br><br>
# Средний уровень <br><br>
# $(-2, 2), (-1, 1), (0, 0), (1, 1), (2, 2)$<br><br>
# Сложный уровень <br><br>
# $(-3, 33), (-2, 31), (-1, 18), (1, -18), (2, -31), (3, -33)$

# %%
### YOUR CODE HERE ###
from sympy import *

# %%
DataPointsDomain = [-2,-1,0,1,2]
DataPointsRange =  [2,1,0,1,2]
x = symbols('x')
s1 = interpolating_spline(4, x, DataPointsDomain, DataPointsRange)
print(s1)
# Out:
# Piecewise((-x**4/6 + 7*x**2/6, (x >= -2) & (x <= 2)))

# %% [markdown]
# f(x)=y=-x**4/6 + 7*x**2/6
# область определения - бесконечность
# f(-x)=-(-x)**4/6 + 7*(-x)**2/6=-x**4/6 + 7*x**2/6 - четная
# y=0 при x=0, -sqrt(7), sqrt(7)
# f(0)=0
# Постоянно возрастает на x=-00;-sqrt(7)/2 и x=0;sqrt(7)/2
# Постоянно убывает на x=-sqrt(7)/2;0 и x=sqrt(7)/2;+00
#
# Хотя подошла бы и функция y=abs(x)

# %%
s1=Piecewise((-x**4/6 + 7*x**2/6, (x >= -4) & (x <= 4)))
plot(s1)

# %%
DataPointsDomain = [-3,-2,-1,1,2,3]
DataPointsRange =  [33,31,18,-18,-31,-33]
x = symbols('x')
s2 = interpolating_spline(5, x, DataPointsDomain, DataPointsRange)
print(s2)
# Out:
# Piecewise((x**5/120 + 19*x**3/24 - 94*x/5, (x >= -3) & (x <= 3)))

# %% [markdown]
# f(x)=y=x**5/120 + 19*x**3/24-94*x/5
# область определения - бесконечность
# f(-x)=(-x)**5/120 + 19*(-x)**3/24-94*(-x)/5=-x**5/120 - 19*x**3/24+94*x/5=-f(x) - нечетная
# y=0 при x=0, x=a=sqrt((-85+sqrt(16249))/2), x=b=-sqrt((-85+sqrt(16249))/2)
# f(0)=0
# Постоянно возрастает на x=-00;b и x=a;00
# Постоянно убывает на x=b;a

# %%
s3=Piecewise((x**5/120 + 19*x**3/24 - 94*x/5, (x >= -10) & (x <= 10)))
plot(s3)
